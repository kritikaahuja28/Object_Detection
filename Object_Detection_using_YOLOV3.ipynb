# %% [markdown]
# <a href="https://colab.research.google.com/github/kritikaahuja28/Object_Detection/blob/master/Object_Detection_using_YOLOV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip '/content/drive/My Drive/license_detection.zip'
# Out:
# Archive:  /content/drive/My Drive/license_detection.zip
#    creating: license_detection/
#    creating: license_detection/custom_cfg/
#   inflating: license_detection/custom_cfg/darknet53.conv.74
#   inflating: license_detection/custom_cfg/license.cfg
#   inflating: license_detection/custom_cfg/license.data
#   inflating: license_detection/custom_cfg/license.names
#   inflating: license_detection/custom_cfg/test.txt
#   inflating: license_detection/custom_cfg/train.txt
#    creating: license_detection/custom_dataset/
#   inflating: license_detection/custom_dataset/driving1.jpg
#   inflating: license_detection/custom_dataset/driving1.txt
#   inflating: license_detection/custom_dataset/driving10.jpg
#   inflating: license_detection/custom_dataset/driving10.txt
#   inflating: license_detection/custom_dataset/driving11.jpg
#   inflating: license_detection/custom_dataset/driving11.txt
#   inflating: license_detection/custom_dataset/driving12.jpg
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 13907 (delta 8), reused 14 (delta 4), pack-reused 13877
# Receiving objects: 100% (13907/13907), 12.47 MiB | 11.29 MiB/s, done.
# Resolving deltas: 100% (9492/9492), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp -a /content/license_detection/custom_cfg /content/darknet/ 
# !cp -a /content/license_detection/custom_dataset /content/darknet/

# %%
# %cd /content/darknet
# !./darknet detector train custom_cfg/license.data custom_cfg/license.cfg custom_cfg/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 583954, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.936222, GIOU: 0.935306), Class: 0.999952, Obj: 0.982065, No Obj: 0.002056, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.004363, iou_loss = 0.009292, total_loss = 0.013655
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.803520, GIOU: 0.802037), Class: 0.999448, Obj: 0.814228, No Obj: 0.000972, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.166971, iou_loss = 0.117856, total_loss = 0.284827
#  total_bbox = 583960, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.818108, GIOU: 0.812916), Class: 0.999934, Obj: 0.996452, No Obj: 0.001587, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.000405, iou_loss = 0.041476, total_loss = 0.041881
# ...

# %%
# on command line
# cd /content/license_detection/
# python3 detect_license.py --image test.jpg
# Out:
# /content/license_detection
# out.shape :  (507, 7)
# 0.91709065  -  0.91701674  - th :  0.5
# [0.5069549  0.09377006 0.59378815 0.1166216  0.91709065 0.
#  0.91701674]
# out.shape :  (2028, 7)
# --------------
# : cannot connect to X server
